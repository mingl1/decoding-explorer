# %%
import rpy2.robjects as ro
from rpy2.robjects import pandas2ri
from rpy2.robjects.packages import importr
import pandas as pd

# Activate automatic conversion between pandas and R dataframes
pandas2ri.activate()

# Load R libraries
r_code = """
library(dplyr)
library(Seurat)
library(SeuratObject)
library(patchwork)
library(openxlsx)
library(ggplot2)
library(umap)
print("Libraries loaded successfully")
"""

ro.r(r_code)
# Out:
# R callback write-console: Error in library(dplyr) : there is no package called ‘dplyr’
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# Cell In[2], line 21
#       6 # Activate automatic conversion between pandas and R dataframes
#       7 # pandas2ri.activate()
#       8
#       9 # Load R libraries
#      10 r_code = """
#      11 library(dplyr)
#      12 library(Seurat)
#    (...)
#      18 print("Libraries loaded successfully")
#      19 """
# ---> 21 ro.r(r_code)
#
# File ~/Desktop/Projects/mistexplorer/MIST-Explorer/.venv/lib/python3.10/site-packages/rpy2/robjects/__init__.py:552, in R.__call__(self, string, invisible, print_r_warnings)
#     550     invisible = self._invisible
#     551 if invisible:
# --> 552     res, visible = rinterface.evalr_expr_with_visible(   # type: ignore
#     553         r_expr
#     554     )
#     555     if not visible[0]:  # type: ignore
#     556         res = None
#
# File ~/Desktop/Projects/mistexplorer/MIST-Explorer/.venv/lib/python3.10/site-packages/rpy2/rinterface/__init__.py:205, in evalr_expr_with_visible(expr, envir)
#     198 r_res = rmemory.protect(
#     199         openrlib.rlib.R_tryEval(
#     200             r_call,
#     201             envir.__sexp__._cdata,  # call context.
#     202             error_occured)
#     203 )
#     204 if error_occured[0]:
# --> 205     raise embedded.RRuntimeError(_rinterface._geterrmessage())
#     206 res = conversion._cdata_to_rinterface(r_res)
#     207 assert isinstance(res, ListSexpVector)
#
# RRuntimeError: Error in library(dplyr) : there is no package called ‘dplyr’

# %%
import rpy2.robjects as ro

# Install packages
r_code = """
# Set CRAN mirror
options(repos = c(CRAN = "https://cloud.r-project.org"))

# List of required packages
packages <- c("dplyr", "Seurat", "SeuratObject", "patchwork", 
              "openxlsx", "ggplot2", "umap")

# Install missing packages
for(pkg in packages) {
  if(!require(pkg, character.only = TRUE, quietly = TRUE)) {
    print(paste("Installing:", pkg))
    install.packages(pkg, dependencies = TRUE)
  } else {
    print(paste("Already installed:", pkg))
  }
}

print("Installation complete!")
"""

ro.r(r_code)
# Out:
# [1] "Installing: dplyr"
# R callback write-console: Installing package into ‘/opt/homebrew/lib/R/4.5/site-library’
# (as ‘lib’ is unspecified)
#
# R callback write-console: also installing the dependencies ‘sys’, ‘askpass’, ‘rappdirs’, ‘lazyeval’, ‘curl’, ‘mime’, ‘openssl’, ‘farver’, ‘labeling’, ‘RColorBrewer’, ‘viridisLite’, ‘base64enc’, ‘cachem’, ‘fastmap’, ‘sass’, ‘bit’, ‘fs’, ‘pkgbuild’, ‘rprojroot’, ‘diffobj’, ‘utf8’, ‘pkgconfig’, ‘profmem’, ‘backports’, ‘stringr’, ‘processx’, ‘digest’, ‘jsonlite’, ‘rex’, ‘httr’, ‘yaml’, ‘blob’, ‘gtable’, ‘isoband’, ‘S7’, ‘scales’, ‘evaluate’, ‘highr’, ‘xfun’, ‘crayon’, ‘prettyunits’, ‘cpp11’, ‘bslib’, ‘fontawesome’, ‘htmltools’, ‘jquerylib’, ‘tinytex’, ‘bit64’, ‘memoise’, ‘plogr’, ‘brio’, ‘desc’, ‘pkgload’, ‘praise’, ‘ps’, ‘waldo’, ‘cli’, ‘generics’, ‘glue’, ‘lifecycle’, ‘magrittr’, ‘pillar’, ‘R6’, ‘rlang’, ‘tibble’, ‘tidyselect’, ‘vctrs’, ‘bench’, ‘broom’, ‘callr’, ‘covr’, ‘DBI’, ‘dbplyr’, ‘ggplot2’, ‘knitr’, ‘Lahman’, ‘lobstr’, ‘microbenchmark’, ‘nycflights13’, ‘purrr’, ‘rmarkdown’, ‘RMySQL’, ‘RPostgreSQL’, ‘RSQLite’, ‘stringi’, ‘testthat’, ‘tidyr’, ‘withr’
#
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/sys_3.4.3.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/askpass_1.2.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/rappdirs_0.3.4.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/lazyeval_0.2.2.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/curl_7.0.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/mime_0.13.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/openssl_2.3.4.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/farver_2.1.2.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/labeling_0.4.3.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/RColorBrewer_1.1-3.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/viridisLite_0.4.2.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/base64enc_0.1-3.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/cachem_1.1.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/fastmap_1.2.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/sass_0.4.10.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/bit_4.6.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/fs_1.6.6.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/pkgbuild_1.4.8.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/rprojroot_2.1.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/diffobj_0.3.6.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/utf8_1.2.6.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/pkgconfig_2.0.3.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/profmem_0.7.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/backports_1.5.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/stringr_1.6.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/processx_3.8.6.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/digest_0.6.39.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/jsonlite_2.0.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/rex_1.2.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/httr_1.4.7.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/yaml_2.3.12.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/blob_1.3.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/gtable_0.3.6.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/isoband_0.3.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/S7_0.2.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/scales_1.4.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/evaluate_1.0.5.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/highr_0.11.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/xfun_0.55.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/crayon_1.5.3.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/prettyunits_1.2.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/cpp11_0.5.2.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/bslib_0.9.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/fontawesome_0.5.3.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/htmltools_0.5.9.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/jquerylib_0.1.4.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/tinytex_0.58.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/bit64_4.6.0-1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/memoise_2.0.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/plogr_0.2.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/brio_1.1.5.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/desc_1.4.3.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/pkgload_1.4.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/praise_1.0.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/ps_1.9.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/waldo_0.6.2.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/cli_3.6.5.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/generics_0.1.4.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/glue_1.8.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/lifecycle_1.0.5.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/magrittr_2.0.4.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/pillar_1.11.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/R6_2.6.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/rlang_1.1.7.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/tibble_3.3.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/tidyselect_1.2.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/vctrs_0.7.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/bench_1.1.4.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/broom_1.0.11.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/callr_3.7.6.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/covr_3.6.5.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/DBI_1.2.3.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/dbplyr_2.5.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/ggplot2_4.0.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/knitr_1.51.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/Lahman_13.0-0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/lobstr_1.1.3.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/microbenchmark_1.5.0.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/nycflights13_1.0.2.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/purrr_1.2.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/rmarkdown_2.30.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/RMySQL_0.11.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/RPostgreSQL_0.7-8.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/RSQLite_2.4.5.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/stringi_1.8.7.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/testthat_3.3.2.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/tidyr_1.3.2.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/withr_3.0.2.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/dplyr_1.1.4.tar.gz'
#
# * installing *source* package ‘sys’ ...
# ** this is package ‘sys’ version ‘3.4.3’
# ** package ‘sys’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using SDK: ‘MacOSX26.2.sdk’
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c exec.c -o exec.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c init.c -o init.o
# clang -std=gnu23 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o sys.so exec.o init.o -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# installing to /opt/homebrew/lib/R/4.5/site-library/00LOCK-sys/00new/sys/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (sys)
# * installing *source* package ‘rappdirs’ ...
# ** this is package ‘rappdirs’ version ‘0.3.4’
# ** package ‘rappdirs’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using SDK: ‘MacOSX26.2.sdk’
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c init.c -o init.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c win-path.c -o win-path.o
# clang -std=gnu23 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o rappdirs.so init.o win-path.o -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# installing to /opt/homebrew/lib/R/4.5/site-library/00LOCK-rappdirs/00new/rappdirs/libs
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (rappdirs)
# * installing *source* package ‘lazyeval’ ...
# ** this is package ‘lazyeval’ version ‘0.2.2’
# ** package ‘lazyeval’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using SDK: ‘MacOSX26.2.sdk’
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c expr.c -o expr.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c init.c -o init.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c interp.c -o interp.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c lazy.c -o lazy.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c name.c -o name.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c utils.c -o utils.o
# clang -std=gnu23 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o lazyeval.so expr.o init.o interp.o lazy.o name.o utils.o -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# installing to /opt/homebrew/lib/R/4.5/site-library/00LOCK-lazyeval/00new/lazyeval/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (lazyeval)
# * installing *source* package ‘curl’ ...
# ** this is package ‘curl’ version ‘7.0.0’
# ** package ‘curl’ successfully unpacked and MD5 sums checked
# ** using staged installation
# Using autobrew bundle: curl-macos-8.14.1-universal.tar.xz
# Using PKG_CFLAGS=-I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include
# Using PKG_LIBS=/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/libcurl -L/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/lib -lapple_nghttp2 -lapple_ssl -lapple_crypto -lldap -lz -dynamic -Wl,-search_paths_first -lkrb5 -framework Security -framework SystemConfiguration -framework CoreFoundation
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c callbacks.c -o callbacks.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c curl.c -o curl.o
# ** libs
# using C compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using SDK: ‘MacOSX26.2.sdk’
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c download.c -o download.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c dryrun.c -o dryrun.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c escape.c -o escape.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c fetch.c -o fetch.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c findport.c -o findport.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c form.c -o form.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c getdate.c -o getdate.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c handle.c -o handle.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c ieproxy.c -o ieproxy.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c init.c -o init.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c interrupt.c -o interrupt.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c multi.c -o multi.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c nslookup.c -o nslookup.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c options.c -o options.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c reflist.c -o reflist.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c split.c -o split.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c ssl.c -o ssl.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c typechecking.c -o typechecking.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c urlparser.c -o urlparser.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c utils.c -o utils.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c version.c -o version.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c winidn.c -o winidn.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/include -DSTRICT_R_HEADERS -DR_NO_REMAP  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c writer.c -o writer.o
# clang -std=gnu23 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o curl.so callbacks.o curl.o download.o dryrun.o escape.o fetch.o findport.o form.o getdate.o handle.o ieproxy.o init.o interrupt.o multi.o nslookup.o options.o reflist.o split.o ssl.o typechecking.o urlparser.o utils.o version.o winidn.o writer.o /private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/libcurl -L/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmplqGs8m/R.INSTALL569d4183238b/curl/.deps/lib -lapple_nghttp2 -lapple_ssl -lapple_crypto -lldap -lz -dynamic -Wl,-search_paths_first -lkrb5 -framework Security -framework SystemConfiguration -framework CoreFoundation -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# installing to /opt/homebrew/lib/R/4.5/site-library/00LOCK-curl/00new/curl/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (curl)
# * installing *source* package ‘mime’ ...
# ** this is package ‘mime’ version ‘0.13’
# ** package ‘mime’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using SDK: ‘MacOSX26.2.sdk’
# installing to /opt/homebrew/lib/R/4.5/site-library/00LOCK-mime/00new/mime/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c init.c -o init.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c rawmatch.c -o rawmatch.o
# clang -std=gnu23 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o mime.so init.o rawmatch.o -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (mime)
# * installing *source* package ‘farver’ ...
# ** this is package ‘farver’ version ‘2.1.2’
# ** package ‘farver’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C++ compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using SDK: ‘MacOSX26.2.sdk’
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c ColorSpace.cpp -o ColorSpace.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c Comparison.cpp -o Comparison.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c Conversion.cpp -o Conversion.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c encode.cpp -o encode.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c farver.cpp -o farver.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c init.cpp -o init.o
# clang++ -std=gnu++17 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o farver.so ColorSpace.o Comparison.o Conversion.o encode.o farver.o init.o -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# installing to /opt/homebrew/lib/R/4.5/site-library/00LOCK-farver/00new/farver/libs
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (farver)
# * installing *source* package ‘labeling’ ...
# ** this is package ‘labeling’ version ‘0.4.3’
# ** package ‘labeling’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (labeling)
# * installing *source* package ‘RColorBrewer’ ...
# ** this is package ‘RColorBrewer’ version ‘1.1-3’
# ** package ‘RColorBrewer’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (RColorBrewer)
# * installing *source* package ‘viridisLite’ ...
# ** this is package ‘viridisLite’ version ‘0.4.2’
# ** package ‘viridisLite’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (viridisLite)
# * installing *source* package ‘base64enc’ ...
# ** this is package ‘base64enc’ version ‘0.1-3’
# ** package ‘base64enc’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using SDK: ‘MacOSX26.2.sdk’
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c base64.c -o base64.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c uriencode.c -o uriencode.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c utf8.c -o utf8.o
# clang -std=gnu23 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o base64enc.so base64.o uriencode.o utf8.o -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# installing to /opt/homebrew/lib/R/4.5/site-library/00LOCK-base64enc/00new/base64enc/libs
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (base64enc)
# * installing *source* package ‘fastmap’ ...
# ** this is package ‘fastmap’ version ‘1.2.0’
# ** package ‘fastmap’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using C++ compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using SDK: ‘MacOSX26.2.sdk’
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -Ilib/  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -DR_NO_REMAP -fPIC  -g -O2   -c fastmap.cpp -o fastmap.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -Ilib/  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c init.c -o init.o
# clang++ -std=gnu++17 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o fastmap.so fastmap.o init.o -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# installing to /opt/homebrew/lib/R/4.5/site-library/00LOCK-fastmap/00new/fastmap/libs
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (fastmap)
# * installing *source* package ‘bit’ ...
# ** this is package ‘bit’ version ‘4.6.0’
# ** package ‘bit’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using SDK: ‘MacOSX26.2.sdk’
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c attrutil.c -o attrutil.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c bit.c -o bit.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c chunkutil.c -o chunkutil.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c clone.c -o clone.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c init.c -o init.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c integerutil.c -o integerutil.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c merge.c -o merge.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c rle.c -o rle.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c sort.c -o sort.o
# clang -std=gnu23 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o bit.so attrutil.o bit.o chunkutil.o clone.o init.o integerutil.o merge.o rle.o sort.o -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# installing to /opt/homebrew/lib/R/4.5/site-library/00LOCK-bit/00new/bit/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (bit)
# * installing *source* package ‘fs’ ...
# ** this is package ‘fs’ version ‘1.6.6’
# ** package ‘fs’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C++ compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using SDK: ‘MacOSX26.2.sdk’
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I./libuv-1.44.2/include -I. -pthread  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c dir.cc -o dir.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I./libuv-1.44.2/include -I. -pthread  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c error.cc -o error.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I./libuv-1.44.2/include -I. -pthread  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c file.cc -o file.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I./libuv-1.44.2/include -I. -pthread  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c fs.cc -o fs.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I./libuv-1.44.2/include -I. -pthread  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c getmode.cc -o getmode.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I./libuv-1.44.2/include -I. -pthread  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c id.cc -o id.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I./libuv-1.44.2/include -I. -pthread  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c init.cc -o init.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I./libuv-1.44.2/include -I. -pthread  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c link.cc -o link.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I./libuv-1.44.2/include -I. -pthread  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c path.cc -o path.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I./libuv-1.44.2/include -I. -pthread  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c utils.cc -o utils.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG -I./libuv-1.44.2/include -I. -pthread  -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c unix/getmode.cc -o unix/getmode.o
# touch libuv-1.44.2/aclocal.m4 && touch libuv-1.44.2/configure && touch libuv-1.44.2/Makefile.in
# (cd libuv-1.44.2 \
# 	&& CC="clang -std=gnu23" CPPFLAGS="-I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include" CFLAGS="-g -O2  -fPIC -fvisibility=hidden -std=c99" AR="ar" RANLIB="ranlib" LDFLAGS="-L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib" ./configure  --quiet)
# rm: conftest.dSYM: is a directory
# ld: warning: -single_module is obsolete
# make --directory=libuv-1.44.2 \
# 		HAVE_DTRACE=0
#   CC       src/libuv_la-fs-poll.lo
#   CC       src/libuv_la-idna.lo
#   CC       src/libuv_la-inet.lo
#   CC       src/libuv_la-random.lo
#   CC       src/libuv_la-strscpy.lo
#   CC       src/libuv_la-threadpool.lo
#   CC       src/libuv_la-timer.lo
#   CC       src/libuv_la-uv-data-getter-setters.lo
#   CC       src/libuv_la-uv-common.lo
#   CC       src/libuv_la-version.lo
#   CC       src/libuv_la-strtok.lo
#   CC       src/unix/libuv_la-async.lo
#   CC       src/unix/libuv_la-core.lo
#   CC       src/unix/libuv_la-dl.lo
#   CC       src/unix/libuv_la-fs.lo
#   CC       src/unix/libuv_la-getaddrinfo.lo
#   CC       src/unix/libuv_la-getnameinfo.lo
#   CC       src/unix/libuv_la-loop-watcher.lo
#   CC       src/unix/libuv_la-loop.lo
#   CC       src/unix/libuv_la-pipe.lo
#   CC       src/unix/libuv_la-poll.lo
#   CC       src/unix/libuv_la-process.lo
#   CC       src/unix/libuv_la-random-devurandom.lo
#   CC       src/unix/libuv_la-signal.lo
#   CC       src/unix/libuv_la-stream.lo
#   CC       src/unix/libuv_la-tcp.lo
#   CC       src/unix/libuv_la-thread.lo
#   CC       src/unix/libuv_la-tty.lo
#   CC       src/unix/libuv_la-udp.lo
#   CC       src/unix/libuv_la-bsd-ifaddrs.lo
#   CC       src/unix/libuv_la-darwin-proctitle.lo
#   CC       src/unix/libuv_la-darwin.lo
#   CC       src/unix/libuv_la-fsevents.lo
#   CC       src/unix/libuv_la-kqueue.lo
#   CC       src/unix/libuv_la-proctitle.lo
#   CC       src/unix/libuv_la-random-getentropy.lo
#   CCLD     libuv.la
# clang++ -std=gnu++17 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o fs.so dir.o error.o file.o fs.o getmode.o id.o init.o link.o path.o utils.o unix/getmode.o ./libuv-1.44.2/.libs/libuv.pa -pthread -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# installing to /opt/homebrew/lib/R/4.5/site-library/00LOCK-fs/00new/fs/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# ...
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG  -I'/opt/homebrew/lib/R/4.5/site-library/Rcpp/include' -I'/opt/homebrew/lib/R/4.5/site-library/RcppEigen/include' -I'/opt/homebrew/lib/R/4.5/site-library/RcppProgress/include' -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2  -c valid_pointer.c -o valid_pointer.o
# clang++ -std=gnu++17 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o Seurat.so ModularityOptimizer.o RModularityOptimizer.o RcppExports.o data_manipulation.o fast_NN_dist.o integration.o snn.o stats.o valid_pointer.o -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# installing to /opt/homebrew/lib/R/4.5/site-library/00LOCK-Seurat/00new/Seurat/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (Seurat)
# R callback write-console:
#
# R callback write-console:
# R callback write-console: The downloaded source packages are in
# 	‘/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmpICePfy/downloaded_packages’
# R callback write-console:
# R callback write-console:
#
# R callback write-console:
# Attaching package: ‘SeuratObject’
#
#
# R callback write-console: The following objects are masked from ‘package:base’:
#
#     intersect, t
# [1] "Already installed: SeuratObject"
# [1] "Already installed: patchwork"
# [1] "Installing: openxlsx"
# R callback write-console: Installing package into ‘/opt/homebrew/lib/R/4.5/site-library’
# (as ‘lib’ is unspecified)
#
# R callback write-console: also installing the dependencies ‘operator.tools’, ‘zip’, ‘formula.tools’
#
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/operator.tools_1.6.3.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/zip_2.3.3.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/formula.tools_1.7.1.tar.gz'
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/openxlsx_4.2.8.1.tar.gz'
#
# * installing *source* package ‘operator.tools’ ...
# ** this is package ‘operator.tools’ version ‘1.6.3’
# ** package ‘operator.tools’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (operator.tools)
# * installing *source* package ‘zip’ ...
# ** this is package ‘zip’ version ‘2.3.3’
# ** package ‘zip’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using SDK: ‘MacOSX26.2.sdk’
# clang -std=gnu23 -g -O2  miniz.c zip.c unixutils.c tools/cmdzip.c -o tools/cmdzip
# clang -std=gnu23 -g -O2  miniz.c zip.c unixutils.c tools/cmdunzip.c -o tools/cmdunzip
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c init.c -o init.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c miniz.c -o miniz.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c rzip.c -o rzip.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c zip.c -o zip.o
# clang -std=gnu23 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG   -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include   -fvisibility=hidden -fPIC  -g -O2  -c unixutils.c -o unixutils.o
# clang -std=gnu23 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o zip.so init.o miniz.o rzip.o zip.o unixutils.o -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# installing via 'install.libs.R' to /opt/homebrew/lib/R/4.5/site-library/00LOCK-zip/00new/zip
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (zip)
# * installing *source* package ‘formula.tools’ ...
# ** this is package ‘formula.tools’ version ‘1.7.1’
# ** package ‘formula.tools’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (formula.tools)
# * installing *source* package ‘openxlsx’ ...
# ** this is package ‘openxlsx’ version ‘4.2.8.1’
# ** package ‘openxlsx’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C++ compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using SDK: ‘MacOSX26.2.sdk’
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG  -I'/opt/homebrew/lib/R/4.5/site-library/Rcpp/include' -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c RcppExports.cpp -o RcppExports.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG  -I'/opt/homebrew/lib/R/4.5/site-library/Rcpp/include' -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c helper_functions.cpp -o helper_functions.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG  -I'/opt/homebrew/lib/R/4.5/site-library/Rcpp/include' -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c load_workbook.cpp -o load_workbook.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG  -I'/opt/homebrew/lib/R/4.5/site-library/Rcpp/include' -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c read_workbook.cpp -o read_workbook.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG  -I'/opt/homebrew/lib/R/4.5/site-library/Rcpp/include' -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c write_data.cpp -o write_data.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG  -I'/opt/homebrew/lib/R/4.5/site-library/Rcpp/include' -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c write_file.cpp -o write_file.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG  -I'/opt/homebrew/lib/R/4.5/site-library/Rcpp/include' -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c write_file_2.cpp -o write_file_2.o
# clang++ -std=gnu++17 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o openxlsx.so RcppExports.o helper_functions.o load_workbook.o read_workbook.o write_data.o write_file.o write_file_2.o -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# installing to /opt/homebrew/lib/R/4.5/site-library/00LOCK-openxlsx/00new/openxlsx/libs
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (openxlsx)
# R callback write-console:
#
# R callback write-console:
# R callback write-console: The downloaded source packages are in
# 	‘/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmpICePfy/downloaded_packages’
# R callback write-console:
# R callback write-console:
# [1] "Already installed: ggplot2"
# [1] "Installing: umap"
# R callback write-console: Installing package into ‘/opt/homebrew/lib/R/4.5/site-library’
# (as ‘lib’ is unspecified)
#
# R callback write-console: trying URL 'https://cloud.r-project.org/src/contrib/umap_0.2.10.0.tar.gz'
#
# R callback write-console: Content type 'application/x-gzip'
# R callback write-console:  length 82451 bytes (80 KB)
#
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console: =
# R callback write-console:
#
# R callback write-console: downloaded 80 KB
#
#
# * installing *source* package ‘umap’ ...
# ** this is package ‘umap’ version ‘0.2.10.0’
# ** package ‘umap’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# using C++ compiler: ‘Apple clang version 17.0.0 (clang-1700.6.3.2)’
# using SDK: ‘MacOSX26.2.sdk’
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG  -I'/opt/homebrew/lib/R/4.5/site-library/Rcpp/include' -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c RcppExports.cpp -o RcppExports.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG  -I'/opt/homebrew/lib/R/4.5/site-library/Rcpp/include' -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c distances.cpp -o distances.o
# clang++ -std=gnu++17 -I"/opt/homebrew/Cellar/r/4.5.2_1/lib/R/include" -DNDEBUG  -I'/opt/homebrew/lib/R/4.5/site-library/Rcpp/include' -I/opt/homebrew/opt/gettext/include -I/opt/homebrew/opt/readline/include -I/opt/homebrew/opt/xz/include -I/opt/homebrew/include    -fPIC  -g -O2   -c optimize.cpp -o optimize.o
# clang++ -std=gnu++17 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -L/opt/homebrew/opt/gettext/lib -L/opt/homebrew/opt/readline/lib -L/opt/homebrew/opt/xz/lib -L/opt/homebrew/lib -o umap.so RcppExports.o distances.o optimize.o -L/opt/homebrew/Cellar/r/4.5.2_1/lib/R/lib -lR
# installing to /opt/homebrew/lib/R/4.5/site-library/00LOCK-umap/00new/umap/libs
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** checking absolute paths in shared objects and dynamic libraries
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (umap)
# R callback write-console:
#
# R callback write-console:
# R callback write-console: The downloaded source packages are in
# 	‘/private/var/folders/t1/tkld7pqd0sqcg2ybx45h9rfh0000gn/T/RtmpICePfy/downloaded_packages’
# R callback write-console:
# R callback write-console:
# [1] "Installation complete!"
# R callback write-console: In addition:
# R callback write-console: Warning messages:
#
# R callback write-console: 1:
# R callback write-console: In install.packages(pkg, dependencies = TRUE) :
# R callback write-console:
#
# R callback write-console:  installation of package ‘units’ had non-zero exit status
#
# R callback write-console: 2:
# R callback write-console: In install.packages(pkg, dependencies = TRUE) :
# R callback write-console:
#
# R callback write-console:  installation of package ‘arrow’ had non-zero exit status
#
# R callback write-console: 3:
# R callback write-console: In install.packages(pkg, dependencies = TRUE) :
# R callback write-console:
#
# R callback write-console:  installation of package ‘qqconf’ had non-zero exit status
#
# R callback write-console: 4:
# R callback write-console: In install.packages(pkg, dependencies = TRUE) :
# R callback write-console:
#
# R callback write-console:  installation of package ‘mutoss’ had non-zero exit status
#
# R callback write-console: 5:
# R callback write-console: In install.packages(pkg, dependencies = TRUE) :
# R callback write-console:
#
# R callback write-console:  installation of package ‘sf’ had non-zero exit status
#
# R callback write-console: 6:
# R callback write-console: In install.packages(pkg, dependencies = TRUE) :
# R callback write-console:
#
# R callback write-console:  installation of package ‘metap’ had non-zero exit status
